# %% [markdown]
# ## Image Retriever Notebook
# We're building our image retriever for training

# %%
import io
import dropbox
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image

# %%
# Let's add our access token 
dbx = dropbox.Dropbox()

processed_data_link = dropbox.files.sharedlink(
    url = "https://www.dropbox.com/scl/fo/ixxiwveladxhvet9zvf6v/AKNqRl7JwGkmoWl-rZFTEWc/processed_data?dl=0&rlkey=vq59z96n9hvefi9jl62jhc41q&subfolder_nav_tracking=1")
